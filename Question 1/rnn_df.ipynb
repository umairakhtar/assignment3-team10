# %%
import pandas as pd
df = pd.read_csv('mod.csv')
df.text=df.text.astype(str)

# %%
df = df.drop(columns='Unnamed: 0')
df.head()
# Out:
#   sentiment                                               text
# 0  positive  Thank you, Ellen. We have a strong 2018, with ...
# 1  positive  Stock-based compensation totaled $2.3 billion....
# 2   neutral  For opening remarks, I will be turning the cal...
# 3  positive  [Operator Instructions]. Our first question wi...
# 4  positive  Hey, thanks. So I guess the question I have an...

# %%
df['sentiment'] = df['sentiment'].replace({'positive': 0,'negative':1,'neutral':2})
df.head()
# Out:
#    sentiment                                               text
# 0          0  Thank you, Ellen. We have a strong 2018, with ...
# 1          0  Stock-based compensation totaled $2.3 billion....
# 2          2  For opening remarks, I will be turning the cal...
# 3          0  [Operator Instructions]. Our first question wi...
# 4          0  Hey, thanks. So I guess the question I have an...

# %%
#RNN input requires array data type,
X, y = (df['text'].values, df['sentiment'].values)

# %% [markdown]
# ###Text data has to be integer encoded before feeding it into the RNN model. This can be easily achieved by using basic tools from the Keras library:

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
tk = Tokenizer(lower = True)
tk.fit_on_texts(X)
X_seq = tk.texts_to_sequences(X)
X_pad = pad_sequences(X_seq, maxlen=1000, padding='post')

# %%
X_pad
# Out:
# array([[ 106,   10, 3962, ...,    0,    0,    0],
#        [ 705,  273,  875, ...,    0,    0,    0],
#        [  13,  917,  467, ...,    0,    0,    0],
#        ...,
#        [  71,   38,   11, ...,    0,    0,    0],
#        [ 489,   23,   22, ...,    0,    0,    0],
#        [ 140, 3037,  350, ...,    0,    0,    0]], dtype=int32)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_pad, y, test_size = 0.2, random_state = 1)

# %%
import numpy as np
from keras.utils import to_categorical
num_classes = len(np.unique(y_train))
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)

# %% [markdown]
# ###Single layer simpleRNN
# where return_sequence is set to False (default)

# %%
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense, Dropout, SimpleRNN
vocabulary_size = len(tk.word_counts.keys())+1
max_words = 1000
batch_size = 32
embedding_size = 32
model = Sequential()
model.add(Embedding(vocabulary_size, embedding_size, input_length=max_words))
model.add(SimpleRNN(32))
model.add(Dense(3, activation='softmax'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_13 (Embedding)     (None, 1000, 32)          205120
# _________________________________________________________________
# simple_rnn_18 (SimpleRNN)    (None, 32)                2080
# _________________________________________________________________
# dense_11 (Dense)             (None, 3)                 99
# =================================================================
# Total params: 207,299
# Trainable params: 207,299
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorboardcolab import *
tbc=TensorBoardColab()
# Out:
# Wait for 8 seconds...
# TensorBoard link:
# https://bfe96253.ngrok.io

# %%
model.fit(X_train, y_train,validation_data=(X_test,y_test),batch_size=batch_size,epochs=20,shuffle=True,callbacks=[TensorBoardColabCallback(tbc)])

# %% [markdown]
# ###Two layer RNN

# %%
model = Sequential()
model.add(Embedding(vocabulary_size, 32,input_length=max_words))
model.add(SimpleRNN(32, return_sequences=True))
#model.add(SimpleRNN(32, return_sequences=True))
#model.add(SimpleRNN(32, return_sequences=True))
model.add(SimpleRNN(32))  # This last layer only returns the last outputs.
model.add(Dense(3, activation='softmax'))

model.summary()
model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_14 (Embedding)     (None, 1000, 32)          205120
# _________________________________________________________________
# simple_rnn_19 (SimpleRNN)    (None, 1000, 32)          2080
# _________________________________________________________________
# simple_rnn_20 (SimpleRNN)    (None, 32)                2080
# _________________________________________________________________
# dense_12 (Dense)             (None, 3)                 99
# =================================================================
# Total params: 209,379
# Trainable params: 209,379
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorboardcolab import *
tbc=TensorBoardColab()
# Out:
# Wait for 8 seconds...
# TensorBoard link:
# https://5bba38b5.ngrok.io

# %%
model.fit(X_train, y_train,validation_data=(X_test,y_test),batch_size=batch_size,epochs=20,shuffle=True,callbacks=[TensorBoardColabCallback(tbc)])
# Out:
# Train on 1317 samples, validate on 330 samples
# Epoch 1/20
# 1317/1317 [==============================] - 68s 51ms/step - loss: 0.5748 - acc: 0.6608 - val_loss: 0.5652 - val_acc: 0.6667
# Epoch 2/20
# 1317/1317 [==============================] - 67s 51ms/step - loss: 0.5647 - acc: 0.6669 - val_loss: 0.5647 - val_acc: 0.6869
# Epoch 3/20
# 1317/1317 [==============================] - 68s 51ms/step - loss: 0.5663 - acc: 0.6576 - val_loss: 0.5711 - val_acc: 0.6667
# Epoch 4/20
# 1317/1317 [==============================] - 67s 51ms/step - loss: 0.5638 - acc: 0.6664 - val_loss: 0.5554 - val_acc: 0.6869
# Epoch 5/20
# 1317/1317 [==============================] - 67s 51ms/step - loss: 0.5655 - acc: 0.6644 - val_loss: 0.5595 - val_acc: 0.6667
# Epoch 6/20
# 1317/1317 [==============================] - 67s 51ms/step - loss: 0.5634 - acc: 0.6634 - val_loss: 0.5591 - val_acc: 0.6667
# Epoch 7/20
# 1317/1317 [==============================] - 67s 51ms/step - loss: 0.5628 - acc: 0.6677 - val_loss: 0.5689 - val_acc: 0.6667
# Epoch 8/20
# 1317/1317 [==============================] - 67s 51ms/step - loss: 0.5626 - acc: 0.6644 - val_loss: 0.5591 - val_acc: 0.6869
# Epoch 9/20
# 1317/1317 [==============================] - 66s 50ms/step - loss: 0.5648 - acc: 0.6568 - val_loss: 0.5569 - val_acc: 0.6808
# Epoch 10/20
# 1317/1317 [==============================] - 66s 50ms/step - loss: 0.5630 - acc: 0.6712 - val_loss: 0.5681 - val_acc: 0.6667
# Epoch 11/20
# 1317/1317 [==============================] - 66s 50ms/step - loss: 0.5642 - acc: 0.6684 - val_loss: 0.5604 - val_acc: 0.6667
# Epoch 12/20
# 1317/1317 [==============================] - 67s 51ms/step - loss: 0.5621 - acc: 0.6732 - val_loss: 0.5644 - val_acc: 0.6667
# Epoch 13/20
# 1317/1317 [==============================] - 67s 51ms/step - loss: 0.5637 - acc: 0.6636 - val_loss: 0.5550 - val_acc: 0.6869
# Epoch 14/20
# 1317/1317 [==============================] - 66s 50ms/step - loss: 0.5624 - acc: 0.6659 - val_loss: 0.5551 - val_acc: 0.6869
# Epoch 15/20
# 1317/1317 [==============================] - 67s 51ms/step - loss: 0.5616 - acc: 0.6732 - val_loss: 0.5610 - val_acc: 0.6667
# Epoch 16/20
# 1317/1317 [==============================] - 66s 50ms/step - loss: 0.5634 - acc: 0.6679 - val_loss: 0.5560 - val_acc: 0.6869
# Epoch 17/20
# 1317/1317 [==============================] - 67s 51ms/step - loss: 0.5634 - acc: 0.6651 - val_loss: 0.5563 - val_acc: 0.6667
# Epoch 18/20
# 1317/1317 [==============================] - 66s 50ms/step - loss: 0.5631 - acc: 0.6596 - val_loss: 0.5572 - val_acc: 0.6869
# Epoch 19/20
# 1317/1317 [==============================] - 66s 50ms/step - loss: 0.5638 - acc: 0.6533 - val_loss: 0.5601 - val_acc: 0.6667
# Epoch 20/20
# 1317/1317 [==============================] - 67s 51ms/step - loss: 0.5626 - acc: 0.6717 - val_loss: 0.5590 - val_acc: 0.6667

# %%
from sklearn.metrics import confusion_matrix
y_pred = model.predict(X_train)
matrix = confusion_matrix(y_train.argmax(axis=1), y_pred.argmax(axis=1))

# %%
y_pred
# Out:
# array([[0.38553756, 0.13320945, 0.4812529 ],
#        [0.38538548, 0.13324724, 0.48136726],
#        [0.38540816, 0.13321693, 0.48137492],
#        ...,
#        [0.38542792, 0.13323006, 0.48134205],
#        [0.3854251 , 0.13318935, 0.4813856 ],
#        [0.38540575, 0.13322994, 0.48136428]], dtype=float32)

# %%
df['sentiment'].value_counts()
# Out:
# 2    833
# 0    657
# 1    157
# Name: sentiment, dtype: int64

# %% [markdown]
# ###LSTM

# %%
from keras.layers import LSTM
model = Sequential()
model.add(Embedding(vocabulary_size, 32,input_length=max_words))
model.add(LSTM(32))
model.add(Dense(3, activation='softmax'))

model.summary()
model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 1000, 32)          205120
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 32)                8320
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 99
# =================================================================
# Total params: 213,539
# Trainable params: 213,539
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorboardcolab import *
tbc=TensorBoardColab()
# Out:
# Wait for 8 seconds...
# TensorBoard link:
# https://271c5f94.ngrok.io

# %%
model.fit(X_train, y_train,validation_data=(X_test,y_test),batch_size=batch_size,epochs=20,shuffle=True,callbacks=[TensorBoardColabCallback(tbc)])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 1317 samples, validate on 330 samples
# Epoch 1/20
# 1317/1317 [==============================] - 85s 64ms/step - loss: 0.5736 - acc: 0.6608 - val_loss: 0.5662 - val_acc: 0.6869
# Epoch 2/20
# 1317/1317 [==============================] - 83s 63ms/step - loss: 0.5640 - acc: 0.6662 - val_loss: 0.5610 - val_acc: 0.6667
# Epoch 3/20
# 1317/1317 [==============================] - 83s 63ms/step - loss: 0.5625 - acc: 0.6641 - val_loss: 0.5581 - val_acc: 0.6667
# Epoch 4/20
# 1317/1317 [==============================] - 83s 63ms/step - loss: 0.5628 - acc: 0.6608 - val_loss: 0.5573 - val_acc: 0.6869
# Epoch 5/20
# 1317/1317 [==============================] - 82s 63ms/step - loss: 0.5632 - acc: 0.6583 - val_loss: 0.5563 - val_acc: 0.6869
# Epoch 6/20
# 1317/1317 [==============================] - 83s 63ms/step - loss: 0.5627 - acc: 0.6651 - val_loss: 0.5611 - val_acc: 0.6667
# Epoch 7/20
# 1317/1317 [==============================] - 83s 63ms/step - loss: 0.5635 - acc: 0.6586 - val_loss: 0.5573 - val_acc: 0.6667
# Epoch 8/20
# 1317/1317 [==============================] - 82s 62ms/step - loss: 0.5619 - acc: 0.6664 - val_loss: 0.5563 - val_acc: 0.6869
# Epoch 9/20
# 1317/1317 [==============================] - 83s 63ms/step - loss: 0.5626 - acc: 0.6621 - val_loss: 0.5625 - val_acc: 0.6667
# Epoch 10/20
# 1317/1317 [==============================] - 83s 63ms/step - loss: 0.5634 - acc: 0.6616 - val_loss: 0.5555 - val_acc: 0.6869
# Epoch 11/20
# 1317/1317 [==============================] - 83s 63ms/step - loss: 0.5628 - acc: 0.6654 - val_loss: 0.5586 - val_acc: 0.6667
# Epoch 12/20
# 1317/1317 [==============================] - 83s 63ms/step - loss: 0.5620 - acc: 0.6608 - val_loss: 0.5569 - val_acc: 0.6869
# Epoch 13/20
# 1317/1317 [==============================] - 83s 63ms/step - loss: 0.5627 - acc: 0.6667 - val_loss: 0.5605 - val_acc: 0.6667
# Epoch 14/20
# 1317/1317 [==============================] - 83s 63ms/step - loss: 0.5628 - acc: 0.6591 - val_loss: 0.5603 - val_acc: 0.6667
# Epoch 15/20
# 1317/1317 [==============================] - 83s 63ms/step - loss: 0.5624 - acc: 0.6603 - val_loss: 0.5560 - val_acc: 0.6869
# Epoch 16/20
# 1317/1317 [==============================] - 83s 63ms/step - loss: 0.5621 - acc: 0.6682 - val_loss: 0.5607 - val_acc: 0.6667
# Epoch 17/20
# 1317/1317 [==============================] - 83s 63ms/step - loss: 0.5626 - acc: 0.6611 - val_loss: 0.5600 - val_acc: 0.6667
# Epoch 18/20
# 1317/1317 [==============================] - 83s 63ms/step - loss: 0.5624 - acc: 0.6667 - val_loss: 0.5583 - val_acc: 0.6667
# Epoch 19/20
# 1317/1317 [==============================] - 84s 64ms/step - loss: 0.5619 - acc: 0.6649 - val_loss: 0.5590 - val_acc: 0.6869
# Epoch 20/20
# 1317/1317 [==============================] - 84s 64ms/step - loss: 0.5633 - acc: 0.6662 - val_loss: 0.5553 - val_acc: 0.6869

# %%
from sklearn.metrics import confusion_matrix
y_pred = model.predict(X_train)
matrix = confusion_matrix(y_train.argmax(axis=1), y_pred.argmax(axis=1))

# %%
print(matrix)
# Out:
# [[  0   0 533]
#  [  0   0 126]
#  [  0   0 658]]
