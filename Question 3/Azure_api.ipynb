# %%
import json
import pandas as pd
import numpy as np
data = pd.read_csv('mod.csv')
data.text=data.text.astype(str)

# %%
text = list(data.text)

# %%
len(text)
# Out:
# 1647

# %%
id_list = [i for i in range(1, len(text)+1)]

text_a = []
for i in range(len(text)):
    dict_doc = {"language": "en",
              "id": str(id_list[i]),
              "text": text[i]}
    text_a.append((dict_doc))

# %%
text_a
# Out:
# [{'id': '1',
#   'language': 'en',
#   'text': 'Thank you, Ellen. We have a strong 2018, with total revenues of $136.8 billion, up 23% over 2017, reflecting the benefit of our ongoing investments to deliver exceptional experiences for users and compelling returns for our advertisers, partners and enterprise customers.'},
#  {'id': '2',
#   'language': 'en',
#   'text': 'Stock-based compensation totaled $2.3 billion. Headcount at the end of the quarter was 98,771, up 4,399 from last quarter. Consistent with prior quarters, the majority of new hires were engineers and product managers. In terms of product areas, the most sizable head count increases were in Cloud for both technical and sales roles.'},
#  {'id': '3',
#   'language': 'en',
#   'text': 'For opening remarks, I will be turning the call over to the Director of Investor Relations, Dave Fildes. Please go ahead.'},
#  {'id': '4',
#   'language': 'en',
# ...

# %%
doc = {"documents": text_a[:1000]}
doc_2 ={"documents": text_a[1000:]}

# %%
import http.client, urllib

accessKey = ''#Key here

text_analytics_base_url = 'eastus.api.cognitive.microsoft.com/text/analytics/v2.0/'
sentiment_api_url = text_analytics_base_url + "sentiment"
print(sentiment_api_url)

# %%
import pprint
headers   = {"Ocp-Apim-Subscription-Key": subscription_key}
response  = requests.post(sentiment_api_url, headers=headers, json=doc2)
result_1_score = response.json()
pprint(result_1_score)
# Out:
# {
#     "documents": [
#         {
#             "id": "1",
#             "score": 0.887542188167572
#         },
#         {
#             "id": "2",
#             "score": 0.832602858543396
#         },
#         {
#             "id": "3",
#             "score": 0.5
#         },
#         {
#             "id": "4",
#             "score": 0.5
#         },
#         {
#             "id": "5",
#             "score": 0.5
#         },
#         {
#             "id": "6",
#             "score": 0.8979083895683289
#         },
#         {
#             "id": "7",
#             "score": 0.9795067310333252
#         },
#         {
#             "id": "8",
#             "score": 0.5
#         },
#         {
#             "id": "9",
#             "score": 0.5
#         },
#         {
#             "id": "10",
#             "score": 0.7653786540031433
#         },
#         {
#             "id": "11",
#             "score": 0.5
#         },
#         {
#             "id": "12",
# ...

# %%
headers   = {"Ocp-Apim-Subscription-Key": subscription_key}
response  = requests.post(sentiment_api_url, headers=headers, json=doc2)
result_2_score = response.json()
pprint(result_2_score)
# Out:
# {
#     "documents": [
#         {
#             "id": "1001",
#             "score": 0.8679423928260803
#         },
#         {
#             "id": "1002",
#             "score": 0.5
#         },
#         {
#             "id": "1003",
#             "score": 0.5
#         },
#         {
#             "id": "1004",
#             "score": 0.5
#         },
#         {
#             "id": "1005",
#             "score": 0.8149823546409607
#         },
#         {
#             "id": "1006",
#             "score": 0.5
#         },
#         {
#             "id": "1007",
#             "score": 0.7552365660667419
#         },
#         {
#             "id": "1008",
#             "score": 0.5
#         },
#         {
#             "id": "1009",
#             "score": 0.9624857902526855
#         },
#         {
#             "id": "1010",
#             "score": 0.8857691287994385
#         },
#         {
#             "id": "1011",
#             "score": 0.5
#         },
#         {
# ...

# %%
res = json.loads(result_1_score)
score_1 = []


for i in range (len(res['documents'])):
    score_1.append(res['documents'][i]['score'])

# %%
res = json.loads(result_2_score)
score_2 = []


for i in range (len(res['documents'])):
    score_2.append(res['documents'][i]['score'])

# %%
score = score_1 + score_2
len(score)
# Out:
# 1647

# %%
score_labels = []

for i in range(len(score)):
    if score[i] > 0.6:
        score_labels.append ('positive')
    elif score[i] < 0.4:
        score_labels.append ('negative')
    elif score[i] < 0.6 and score[i] > 0.4:
        score_labels.append ('neutral')

# %%
len(score_labels)
# Out:
# 1647

# %%
dic = {
    'text': text,
    'sentiment_predicted': score_labels,
    'score': score
}

azure_df = pd.DataFrame.from_dict(dic)
azure_df.to_csv('azure_df.csv')
